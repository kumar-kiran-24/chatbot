# %%
from dotenv import load_dotenv
import os 


from langchain_core.messages import HumanMessage

# %%
api_key=os.getenv("HF_TOKEN")

from langchain.chat_models import init_chat_model

model = init_chat_model(
    "nvidia/personaplex-7b-v1",
    # Kwargs passed to the model:
    temperature=0.7,
    timeout=30,
    max_tokens=1000,

)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 5
#       1 api_key=os.getenv("HF_TOKEN")
#       3 from langchain.chat_models import init_chat_model
# ----> 5 model = init_chat_model(
#       6     "nvidia/personaplex-7b-v1",
#       7     # Kwargs passed to the model:
#       8     temperature=0.7,
#       9     timeout=30,
#      10     max_tokens=1000,
#      11
#      12 )
#
# File ~/miniconda3/lib/python3.13/site-packages/langchain/chat_models/base.py:464, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     456     warnings.warn(
#     457         f"{config_prefix=} has been set but no fields are configurable. Set "
#     458         f"`configurable_fields=(...)` to specify the model params that are "
#     459         f"configurable.",
#     460         stacklevel=2,
#     461     )
#     463 if not configurable_fields:
# --> 464     return _init_chat_model_helper(
#     465         cast("str", model),
#     466         model_provider=model_provider,
#     467         **kwargs,
#     468     )
#     469 if model:
#     470     kwargs["model"] = model
#
# File ~/miniconda3/lib/python3.13/site-packages/langchain/chat_models/base.py:486, in _init_chat_model_helper(model, model_provider, **kwargs)
#     480 def _init_chat_model_helper(
#     481     model: str,
#     482     *,
#     483     model_provider: str | None = None,
#     484     **kwargs: Any,
#     485 ) -> BaseChatModel:
# --> 486     model, model_provider = _parse_model(model, model_provider)
#     487     creator_func = _get_chat_model_creator(model_provider)
#     488     return creator_func(model=model, **kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/langchain/chat_models/base.py:582, in _parse_model(model, model_provider)
#     574     supported_list = ", ".join(sorted(_BUILTIN_PROVIDERS))
#     575     msg = (
#     576         f"Unable to infer model provider for {model=}. "
#     577         f"Please specify 'model_provider' directly.\n\n"
#    (...)    580         f"https://docs.langchain.com/oss/python/integrations/providers"
#     581     )
# --> 582     raise ValueError(msg)
#     584 # Normalize provider name
#     585 model_provider = model_provider.replace("-", "_").lower()
#
# ValueError: Unable to infer model provider for model='nvidia/personaplex-7b-v1'. Please specify 'model_provider' directly.
#
# Supported providers: anthropic, azure_ai, azure_openai, bedrock, bedrock_converse, cohere, deepseek, fireworks, google_anthropic_vertex, google_genai, google_vertexai, groq, huggingface, ibm, mistralai, nvidia, ollama, openai, perplexity, together, upstage, xai
#
# For help with specific providers, see: https://docs.langchain.com/oss/python/integrations/providers

# %%
model.invoke([HumanMessage(content="my name is kiran i am the gen ai engineer")])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 model.invoke([HumanMessage(content="my name is kiran i am the gen ai engineer")])
#
# File ~/miniconda3/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:402, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     388 @override
#     389 def invoke(
#     390     self,
#    (...)    395     **kwargs: Any,
#     396 ) -> AIMessage:
#     397     config = ensure_config(config)
#     398     return cast(
#     399         "AIMessage",
#     400         cast(
#     401             "ChatGeneration",
# --> 402             self.generate_prompt(
#     403                 [self._convert_input(input)],
#     404                 stop=stop,
#     405                 callbacks=config.get("callbacks"),
#     406                 tags=config.get("tags"),
#     407                 metadata=config.get("metadata"),
#     408                 run_name=config.get("run_name"),
#     409                 run_id=config.pop("run_id", None),
#     410                 **kwargs,
#     411             ).generations[0][0],
#     412         ).message,
#     413     )
#
# File ~/miniconda3/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1123, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1114 @override
#    1115 def generate_prompt(
#    1116     self,
#    (...)   1120     **kwargs: Any,
#    1121 ) -> LLMResult:
#    1122     prompt_messages = [p.to_messages() for p in prompts]
# -> 1123     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:933, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     930 for i, m in enumerate(input_messages):
#     931     try:
#     932         results.append(
# --> 933             self._generate_with_cache(
#     934                 m,
#     935                 stop=stop,
#     936                 run_manager=run_managers[i] if run_managers else None,
#     937                 **kwargs,
#     938             )
#     939         )
#     940     except BaseException as e:
#     941         if run_managers:
#
# File ~/miniconda3/lib/python3.13/site-packages/langchain_core/language_models/chat_models.py:1235, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1233     result = generate_from_stream(iter(chunks))
#    1234 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1235     result = self._generate(
#    1236         messages, stop=stop, run_manager=run_manager, **kwargs
#    1237     )
#    1238 else:
#    1239     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~/miniconda3/lib/python3.13/site-packages/langchain_huggingface/chat_models/huggingface.py:752, in ChatHuggingFace._generate(self, messages, stop, run_manager, stream, **kwargs)
#     750     answer = self.llm.client.chat_completion(messages=message_dicts, **params)
#     751     return self._create_chat_result(answer)
# --> 752 llm_input = self._to_chat_prompt(messages)
#     754 if should_stream:
#     755     stream_iter = self.llm._stream(
#     756         llm_input, stop=stop, run_manager=run_manager, **kwargs
#     757     )
#
# File ~/miniconda3/lib/python3.13/site-packages/langchain_huggingface/chat_models/huggingface.py:962, in ChatHuggingFace._to_chat_prompt(self, messages)
#     958     raise ValueError(msg)
#     960 messages_dicts = [self._to_chatml_format(m) for m in messages]
# --> 962 return self.tokenizer.apply_chat_template(
#     963     messages_dicts, tokenize=False, add_generation_prompt=True
#     964 )
#
# File ~/miniconda3/lib/python3.13/site-packages/transformers/tokenization_utils_base.py:1647, in PreTrainedTokenizerBase.apply_chat_template(self, conversation, tools, documents, chat_template, add_generation_prompt, continue_final_message, tokenize, padding, truncation, max_length, return_tensors, return_dict, return_assistant_tokens_mask, tokenizer_kwargs, **kwargs)
#    1644 if tokenizer_kwargs is None:
#    1645     tokenizer_kwargs = {}
# -> 1647 chat_template = self.get_chat_template(chat_template, tools)
#    1649 if isinstance(conversation, (list, tuple)) and (
#    1650     isinstance(conversation[0], (list, tuple)) or hasattr(conversation[0], "messages")
#    1651 ):
#    1652     conversations = conversation
#
# File ~/miniconda3/lib/python3.13/site-packages/transformers/tokenization_utils_base.py:1825, in PreTrainedTokenizerBase.get_chat_template(self, chat_template, tools)
#    1823         chat_template = self.chat_template
#    1824     else:
# -> 1825         raise ValueError(
#    1826             "Cannot use chat template functions because tokenizer.chat_template is not set and no template "
#    1827             "argument was passed! For information about writing templates and setting the "
#    1828             "tokenizer.chat_template attribute, please see the documentation at "
#    1829             "https://huggingface.co/docs/transformers/main/en/chat_templating"
#    1830         )
#    1832 return chat_template
#
# ValueError: Cannot use chat template functions because tokenizer.chat_template is not set and no template argument was passed! For information about writing templates and setting the tokenizer.chat_template attribute, please see the documentation at https://huggingface.co/docs/transformers/main/en/chat_templating

# %%
prompt="you are the ai assitant give the better response to the user using the internal knowledege "

llm=prompt|model
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 prompt="you are the ai assitant give the better response to the user using the internal knowledege "
# ----> 3 llm=prompt|model
#
# File ~/miniconda3/lib/python3.13/site-packages/langchain_core/runnables/base.py:656, in __ror__(self, other)
#     639 def __ror__(
#     640     self,
#     641     other: Runnable[Other, Any]
#    (...)    645     | Mapping[str, Runnable[Other, Any] | Callable[[Other], Any] | Any],
#     646 ) -> RunnableSerializable[Other, Output]:
#     647     """Runnable "reverse-or" operator.
#     648
#     649     Compose this `Runnable` with another object to create a
#     650     `RunnableSequence`.
#     651
#     652     Args:
#     653         other: Another `Runnable` or a `Runnable`-like object.
#     654
#     655     Returns:
# --> 656         A new `Runnable`.
#     657     """
#     658     return RunnableSequence(coerce_to_runnable(other), self)
#
# File ~/miniconda3/lib/python3.13/site-packages/langchain_core/runnables/base.py:6062, in coerce_to_runnable(thing)
#    6053 def listener_config_factory(config: RunnableConfig) -> RunnableConfig:
#    6054     return {
#    6055         "callbacks": [
#    6056             RootListenersTracer(
#    6057                 config=config,
#    6058                 on_start=on_start,
#    6059                 on_end=on_end,
#    6060                 on_error=on_error,
#    6061             )
# -> 6062         ],
#    6063     }
#
# TypeError: Expected a Runnable, callable or dict.Instead got an unsupported type: <class 'str'>

# %%
 # !pip install langchain-anthropic
# Out:
# Collecting langchain-anthropic
#   Downloading langchain_anthropic-1.3.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting anthropic<1.0.0,>=0.78.0 (from langchain-anthropic)
#   Downloading anthropic-0.83.0-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.11 in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from langchain-anthropic) (1.2.14)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from langchain-anthropic) (2.12.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from anthropic<1.0.0,>=0.78.0->langchain-anthropic) (4.12.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from anthropic<1.0.0,>=0.78.0->langchain-anthropic) (1.9.0)
# Collecting docstring-parser<1,>=0.15 (from anthropic<1.0.0,>=0.78.0->langchain-anthropic)
#   Downloading docstring_parser-0.17.0-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from anthropic<1.0.0,>=0.78.0->langchain-anthropic) (0.28.1)
# Collecting jiter<1,>=0.4.0 (from anthropic<1.0.0,>=0.78.0->langchain-anthropic)
#   Downloading jiter-0.13.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: sniffio in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from anthropic<1.0.0,>=0.78.0->langchain-anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from anthropic<1.0.0,>=0.78.0->langchain-anthropic) (4.15.0)
# Requirement already satisfied: idna>=2.8 in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from anyio<5,>=3.5.0->anthropic<1.0.0,>=0.78.0->langchain-anthropic) (3.11)
# Requirement already satisfied: certifi in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from httpx<1,>=0.25.0->anthropic<1.0.0,>=0.78.0->langchain-anthropic) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from httpx<1,>=0.25.0->anthropic<1.0.0,>=0.78.0->langchain-anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic<1.0.0,>=0.78.0->langchain-anthropic) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-anthropic) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-anthropic) (0.5.1)
# Requirement already satisfied: packaging>=23.2.0 in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-anthropic) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-anthropic) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-anthropic) (9.1.2)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from langchain-core<2.0.0,>=1.2.11->langchain-anthropic) (0.12.0)
# Requirement already satisfied: jsonpointer>=1.9 in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.11->langchain-anthropic) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-anthropic) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-anthropic) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-anthropic) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-anthropic) (0.24.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (0.6.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from pydantic<3.0.0,>=2.7.4->langchain-anthropic) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-anthropic) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/kirankumars/miniconda3/lib/python3.13/site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.11->langchain-anthropic) (2.6.1)
# Downloading langchain_anthropic-1.3.3-py3-none-any.whl (46 kB)
# Downloading anthropic-0.83.0-py3-none-any.whl (456 kB)
# Downloading docstring_parser-0.17.0-py3-none-any.whl (36 kB)
# Downloading jiter-0.13.0-cp313-cp313-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (359 kB)
# Installing collected packages: jiter, docstring-parser, anthropic, langchain-anthropic
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [langchain-anthropic]m2/4 [anthropic]
# Successfully installed anthropic-0.83.0 docstring-parser-0.17.0 jiter-0.13.0 langchain-anthropic-1.3.3

# %%
from langchain.messages import HumanMessage, AIMessage, SystemMessage

conversation = [
    SystemMessage("You are a helpful assistant that translates English to French."),
    HumanMessage("Translate: I love programming."),
    AIMessage("J'adore la programmation."),
    HumanMessage("Translate: I love building applications.")
]

response = model.invoke(conversation)
print(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       1 from langchain.messages import HumanMessage, AIMessage, SystemMessage
#       3 conversation = [
#       4     SystemMessage("You are a helpful assistant that translates English to French."),
#       5     HumanMessage("Translate: I love programming."),
#       6     AIMessage("J'adore la programmation."),
#       7     HumanMessage("Translate: I love building applications.")
#       8 ]
# ---> 10 response = model.invoke(conversation)
#      11 print(response)
#
# NameError: name 'model' is not defined
